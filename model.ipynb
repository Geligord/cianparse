# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from catboost import CatBoostRegressor, Pool
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold

import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data_for_model.csv')
data
# Out:
#                                            link  post_time  is_apartment  \
# 0     https://perm.cian.ru/sale/flat/293792898/          0         False
# 1     https://perm.cian.ru/sale/flat/292418262/          0         False
# 2     https://perm.cian.ru/sale/flat/287711385/          0         False
# 3     https://perm.cian.ru/sale/flat/292754714/          0         False
# 4     https://perm.cian.ru/sale/flat/289457307/          0         False
# ...                                         ...        ...           ...
# 3143  https://perm.cian.ru/sale/flat/294005202/          1         False
# 3144  https://perm.cian.ru/sale/flat/292951362/         21         False
# 3145  https://perm.cian.ru/sale/flat/293782136/          8         False
# 3146  https://perm.cian.ru/sale/flat/292988411/         24         False
# 3147  https://perm.cian.ru/sale/flat/293389609/         16         False
#
#       floor  floors_count  rooms  total_meters  price_per_m2     price  \
# 0         2             5    1.0          32.0        109375   3500000
# 1         2            27    1.0          27.0         92592   2500000
# 2         3             9    1.0          25.7        141634   3640000
# 3         1            16    1.0          37.7         98143   3700000
# 4         8             9    1.0          28.0         75714   2120000
# ...     ...           ...    ...           ...           ...       ...
# 3143      2             5    4.0          61.4         83876   5150000
# 3144      1             5    4.0          62.0         83870   5200000
# 3145      8             9    1.0          43.4        142857   6200000
# 3146      7            16    4.0          81.2         81280   6600000
# 3147      7            10    3.0          93.4        148822  13900000
#
#       year_of_construction  ...  window_view_Во двор  window_view_На улицу  \
# 0                   1973.0  ...                 True                 False
# 1                   2016.0  ...                 True                 False
# 2                   2023.0  ...                False                  True
# 3                   2011.0  ...                 True                 False
# 4                   1991.0  ...                False                  True
# ...                    ...  ...                  ...                   ...
# 3143                1973.0  ...                False                 False
# 3144                1968.0  ...                 True                 False
# 3145                2014.0  ...                False                  True
# 3146                1992.0  ...                False                 False
# 3147                2001.0  ...                False                 False
#
#       window_view_На улицу и двор  district_Дзержинский  \
# 0                           False                 False
# 1                           False                 False
# 2                           False                 False
# 3                           False                  True
# 4                           False                 False
# ...                           ...                   ...
# 3143                         True                 False
# 3144                        False                 False
# 3145                        False                  True
# 3146                         True                 False
# 3147                         True                  True
#
#       district_Индустриальный  district_Кировский  district_Ленинский  \
# 0                        True               False               False
# 1                       False               False               False
# 2                       False               False               False
# 3                       False               False               False
# 4                       False               False               False
# ...                       ...                 ...                 ...
# 3143                    False               False               False
# 3144                    False               False               False
# 3145                    False               False               False
# 3146                    False               False               False
# 3147                    False               False               False
#
#       district_Мотовилихинский  district_Орджоникидзевский  \
# 0                        False                       False
# 1                        False                        True
# 2                         True                       False
# 3                        False                       False
# 4                        False                        True
# ...                        ...                         ...
# 3143                     False                       False
# 3144                     False                       False
# 3145                     False                       False
# 3146                      True                       False
# 3147                     False                       False
#
#       district_Свердловский
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ...                     ...
# 3143                   True
# 3144                   True
# 3145                  False
# 3146                  False
# 3147                  False
#
# [3148 rows x 51 columns]

# %%
X = data.drop(columns=['link', 'price'])
y = data['price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %%
# Initialize CatBoost Regressor
cat_model = CatBoostRegressor(
    loss_function='MAE', 
    iterations=2000, 
    learning_rate=0.05, 
    depth=3, 
    verbose=200
)

# Define the k-fold cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Lists to store results
mae_scores = []

# Loop through each fold
for train_index, val_index in kf.split(X_train):
    X_train_fold, X_val_fold = X_train.iloc[train_index], X_train.iloc[val_index]
    y_train_fold, y_val_fold = y_train.iloc[train_index], y_train.iloc[val_index]

    # Train the model on the current fold
    cat_model.fit(X_train_fold, y_train_fold, eval_set=(X_val_fold, y_val_fold), early_stopping_rounds=100)
    
    # Predict on the validation data
    y_pred = cat_model.predict(X_val_fold)
    
    # Calculate MAE for the current fold
    mae = mean_absolute_error(y_val_fold, y_pred)
    mae_scores.append(mae)

# Calculate the average MAE across all folds
average_mae = np.mean(mae_scores)

print(f"Average MAE across all folds: {average_mae:.2f}")
# Out:
# 0:	learn: 2284249.1993347	test: 2200976.7409118	best: 2200976.7409118 (0)	total: 11.5ms	remaining: 22.9s
# 200:	learn: 199512.5595117	test: 212690.5217280	best: 212690.5217280 (200)	total: 335ms	remaining: 2.99s
# 400:	learn: 151294.7433845	test: 183193.2471688	best: 183193.2471688 (400)	total: 650ms	remaining: 2.59s
# 600:	learn: 122379.1482499	test: 169093.3811374	best: 169093.3811374 (600)	total: 888ms	remaining: 2.07s
# 800:	learn: 106904.5515479	test: 160468.1327769	best: 160460.4343683 (799)	total: 1.13s	remaining: 1.68s
# 1000:	learn: 98934.7452210	test: 155238.8554572	best: 155238.8554572 (1000)	total: 1.33s	remaining: 1.33s
# 1200:	learn: 91576.6589176	test: 152032.1189922	best: 152032.1189922 (1200)	total: 1.54s	remaining: 1.02s
# 1400:	learn: 85877.9751893	test: 149796.7665032	best: 149785.8273229 (1398)	total: 1.76s	remaining: 753ms
# 1600:	learn: 82170.0512585	test: 148718.0656358	best: 148718.0656358 (1600)	total: 1.98s	remaining: 494ms
# 1800:	learn: 78416.5249798	test: 147333.1916521	best: 147333.1916521 (1800)	total: 2.21s	remaining: 244ms
# 1999:	learn: 74820.8753743	test: 145681.5369003	best: 145681.5369003 (1999)	total: 2.42s	remaining: 0us
#
# bestTest = 145681.5369
# bestIteration = 1999
#
# 0:	learn: 2267925.4965405	test: 2266352.6773177	best: 2266352.6773177 (0)	total: 17.1ms	remaining: 34.2s
# 200:	learn: 211059.5884118	test: 220399.4487160	best: 220399.4487160 (200)	total: 256ms	remaining: 2.29s
# 400:	learn: 143626.4069960	test: 165108.6780754	best: 165108.6780754 (400)	total: 465ms	remaining: 1.85s
# 600:	learn: 123708.4590125	test: 153525.7304057	best: 153525.7304057 (600)	total: 686ms	remaining: 1.6s
# 800:	learn: 111553.0052618	test: 142962.4624154	best: 142958.8326716 (799)	total: 904ms	remaining: 1.35s
# 1000:	learn: 102074.1862647	test: 137514.5773333	best: 137514.5773333 (1000)	total: 1.11s	remaining: 1.11s
# 1200:	learn: 94731.0319148	test: 133367.9856495	best: 133367.9856495 (1200)	total: 1.33s	remaining: 885ms
# 1400:	learn: 89774.3083336	test: 131114.7186299	best: 131114.7186299 (1400)	total: 1.54s	remaining: 660ms
# 1600:	learn: 86345.6223028	test: 129130.8852938	best: 129130.8852938 (1600)	total: 1.76s	remaining: 439ms
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 128678.7029
# bestIteration = 1631
#
# Shrink model to first 1632 iterations.
# 0:	learn: 2255688.6456136	test: 2322534.6344069	best: 2322534.6344069 (0)	total: 1.54ms	remaining: 3.08s
# 200:	learn: 191248.9268788	test: 270456.5362053	best: 270456.5362053 (200)	total: 227ms	remaining: 2.03s
# 400:	learn: 142722.6348141	test: 221701.0390272	best: 221701.0390272 (400)	total: 456ms	remaining: 1.82s
# 600:	learn: 122721.0903558	test: 203366.5207315	best: 203366.5207315 (600)	total: 673ms	remaining: 1.57s
# 800:	learn: 107434.6339824	test: 190000.7892629	best: 189983.8225539 (796)	total: 907ms	remaining: 1.36s
# 1000:	learn: 99215.6460027	test: 181221.1409545	best: 181218.4884231 (999)	total: 1.13s	remaining: 1.13s
# 1200:	learn: 93310.7459312	test: 176971.0555329	best: 176971.0555329 (1200)	total: 1.35s	remaining: 902ms
# 1400:	learn: 87253.8219840	test: 171373.8881314	best: 171340.4806224 (1399)	total: 1.57s	remaining: 672ms
# 1600:	learn: 82537.6918065	test: 166744.6384168	best: 166744.6384168 (1600)	total: 1.79s	remaining: 446ms
# 1800:	learn: 78520.3532132	test: 163034.1259164	best: 163034.1259164 (1800)	total: 2.01s	remaining: 222ms
# 1999:	learn: 75386.8938526	test: 160532.2968335	best: 160530.0958482 (1998)	total: 2.23s	remaining: 0us
#
# bestTest = 160530.0958
# bestIteration = 1998
#
# Shrink model to first 1999 iterations.
# 0:	learn: 2269742.0068229	test: 2267122.0306688	best: 2267122.0306688 (0)	total: 1.3ms	remaining: 2.6s
# 200:	learn: 208906.0098804	test: 209701.0474176	best: 209701.0474176 (200)	total: 221ms	remaining: 1.98s
# 400:	learn: 152165.0399620	test: 166697.8836802	best: 166697.8836802 (400)	total: 438ms	remaining: 1.75s
# 600:	learn: 126602.6110728	test: 149761.4063546	best: 149616.1219780 (596)	total: 654ms	remaining: 1.52s
# 800:	learn: 110630.2524778	test: 142757.2864934	best: 142757.2864934 (800)	total: 866ms	remaining: 1.3s
# 1000:	learn: 100350.3240782	test: 137581.7024144	best: 137581.7024144 (1000)	total: 1.07s	remaining: 1.07s
# 1200:	learn: 94750.9098643	test: 132687.3970729	best: 132642.9355004 (1189)	total: 1.31s	remaining: 873ms
# 1400:	learn: 90334.2535048	test: 127949.6884118	best: 127926.6211385 (1395)	total: 1.54s	remaining: 658ms
# 1600:	learn: 86084.0657606	test: 125877.7919060	best: 125877.7919060 (1600)	total: 1.75s	remaining: 437ms
# 1800:	learn: 82263.6958829	test: 123155.0266484	best: 123147.0937570 (1798)	total: 1.97s	remaining: 218ms
# 1999:	learn: 79848.3864466	test: 121746.1910355	best: 121744.8826558 (1967)	total: 2.19s	remaining: 0us
#
# bestTest = 121744.8827
# bestIteration = 1967
#
# Shrink model to first 1968 iterations.
# 0:	learn: 2263701.3582212	test: 2290881.3914558	best: 2290881.3914558 (0)	total: 1.47ms	remaining: 2.93s
# 200:	learn: 223896.5605434	test: 233486.3293883	best: 233486.3293883 (200)	total: 217ms	remaining: 1.95s
# 400:	learn: 158485.0120043	test: 173142.6329548	best: 173142.6329548 (400)	total: 433ms	remaining: 1.73s
# 600:	learn: 131588.8530044	test: 153408.7987222	best: 153408.7987222 (600)	total: 646ms	remaining: 1.5s
# 800:	learn: 118100.0778577	test: 142982.0444264	best: 142982.0444264 (800)	total: 878ms	remaining: 1.31s
# 1000:	learn: 109961.8709066	test: 138611.2954042	best: 138484.4204132 (995)	total: 1.08s	remaining: 1.08s
# 1200:	learn: 103964.8198178	test: 134099.7672042	best: 134099.7672042 (1200)	total: 1.3s	remaining: 864ms
# 1400:	learn: 98925.4411638	test: 131522.0081203	best: 131522.0081203 (1400)	total: 1.52s	remaining: 648ms
# 1600:	learn: 94935.8512645	test: 129465.3649664	best: 129455.0941822 (1597)	total: 1.74s	remaining: 433ms
# 1800:	learn: 91207.6219742	test: 127631.0707854	best: 127631.0707854 (1800)	total: 1.95s	remaining: 215ms
# 1999:	learn: 88581.4218131	test: 126422.7165532	best: 126422.7165532 (1999)	total: 2.17s	remaining: 0us
#
# bestTest = 126422.7166
# bestIteration = 1999
#
# Average MAE across all folds: 136611.59

# %%
threshold_percentage = 10  # e.g., 10%

# Predict prices for the entire dataset
predicted_prices = cat_model.predict(X)

# Calculate the difference between predicted and actual prices in terms of percentage
price_difference_percentage = (predicted_prices - y) / y * 100

# Find indices where the real price is below the predicted price by more than the threshold
underpriced_mask = price_difference_percentage > threshold_percentage

# Construct a DataFrame with the results
results_df = pd.DataFrame({
    'Link': data['link'][underpriced_mask],
    'Actual Price': y[underpriced_mask],
    'Predicted Price': predicted_prices[underpriced_mask],
    'Difference (%)': price_difference_percentage[underpriced_mask]
})

# Display or save the results
results_df
# Out:
#                                            Link  Actual Price  \
# 322   https://perm.cian.ru/sale/flat/286135070/       7459300
# 325   https://perm.cian.ru/sale/flat/287479058/      11750000
# 338   https://perm.cian.ru/sale/flat/288974730/       2100000
# 647   https://perm.cian.ru/sale/flat/285871513/       7759800
# 1772  https://perm.cian.ru/sale/flat/270457443/       3100000
# 2161  https://perm.cian.ru/sale/flat/284978757/        700000
# 2163  https://perm.cian.ru/sale/flat/292045196/       2490000
# 3019  https://perm.cian.ru/sale/flat/290782592/       1300000
# 3034  https://perm.cian.ru/sale/flat/293311437/       1690000
# 3123  https://perm.cian.ru/sale/flat/293171734/      15000000
# 3137  https://perm.cian.ru/sale/flat/292956399/       1750000
#
#       Predicted Price  Difference (%)
# 322      8.576059e+06       14.971363
# 325      1.317239e+07       12.105424
# 338      2.314904e+06       10.233518
# 647      8.676518e+06       11.813682
# 1772     4.499586e+06       45.147921
# 2161     2.414789e+06      244.969875
# 2163     2.932421e+06       17.767928
# 3019     1.687640e+06       29.818429
# 3034     1.922159e+06       13.737241
# 3123     1.685816e+07       12.387733
# 3137     1.972213e+06       12.697900
